# %%
# -*- coding: utf-8 -*- Line 2
#----------------------------------------------------------------------------
# Project     : Price Alarm System Enhancement Draft
# Created By  : Eungi Cho
# Created Date: 26/05/22
# Updated Date: 03/06/22
# version ='1.0'
# ---------------------------------------------------------------------------

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import csv

warnings.filterwarnings("ignore")
plt.style.use('default')

# %%
import pathlib
print(pathlib.Path().absolute())
df_raw = pd.read_csv('/Users/cho-eungi/Practice/CSV/market_entry_price.csv')
print(df_raw.shape)
# print(df_raw.isnull().sum())
df_raw = df_raw.drop_duplicates()
df_raw.head()
# Out:
# /Users/cho-eungi/Practice/Tridge
# (10619563, 11)
#    source_id       country  market_id  product_id  entry_id currency  \
# 0        201  South Africa       1487         131  92926374      ZAR
# 1         39         India        810         490  41039702      INR
# 2         41         India       2188         133  50157058      INR
# 3        556    Bangladesh       6581         545  84458922      BDT
# 4        150        Turkey       2482         126  58387432      TRY
#
#   final_unit        date  price_min  price_max  price_avg
# 0         kg  2020-07-20      19.64       21.2     19.956
# 1         kg  2020-07-06      11.80       12.5     12.200
# 2         kg  2020-07-06      50.00       52.7     51.400
# 3         kg  2020-07-13    4400.00     4800.0   4600.000
# 4        NaN  2020-07-13      10.00       15.0     11.288

# %%
# Create Test df
entry_lst = np.sort(df_raw['entry_id'].unique())
np.random.seed(0)
sample_entry = np.random.choice(entry_lst, 1000)
test_df = df_raw.loc[df_raw['entry_id'].isin(sample_entry)].sort_values(
    by = ['source_id', 'market_id', 'entry_id', 'date']).copy()
test_df['date'] = pd.to_datetime(test_df['date'])
test_df
# Out:
#          source_id      country  market_id  product_id   entry_id currency  \
# 9270545          1  Netherlands       2775          99   41581966      USD
# 9045476          1  Netherlands       2775          99   41581966      USD
# 9235582          1  Netherlands       2775          99   41581966      USD
# 3920876          1  Netherlands       2782         113   41000912      USD
# 3821445          1  Netherlands       2782         113   41000912      USD
# ...            ...          ...        ...         ...        ...      ...
# 8855661        730      Vietnam       8784       15269  119373567      VND
# 8855655        730      Vietnam       8784       15269  119373567      VND
# 8855647        730      Vietnam       8784       15269  119373567      VND
# 8855659        730      Vietnam       8784       15269  119373567      VND
# 8883371        730      Vietnam       8784       15269  119373567      VND
#
#         final_unit       date  price_min  price_max  price_avg
# 9270545         kg 2020-04-20      15.96      15.96     15.960
# 9045476         kg 2020-06-15       8.96       8.96      8.960
# 9235582         kg 2020-07-20       8.16       8.16      8.160
# 3920876         kg 2020-04-27      21.96      21.96     21.960
# 3821445         kg 2020-05-04      18.75      22.22     20.485
# ...            ...        ...        ...        ...        ...
# 8855661         kg 2022-03-28   22000.00   22000.00  22000.000
# 8855655         kg 2022-04-04   20500.00   20500.00  20500.000
# 8855647         kg 2022-04-11   20500.00   20500.00  20500.000
# 8855659         kg 2022-04-18   19750.00   19750.00  19750.000
# 8883371         kg 2022-04-25   18750.00   18750.00  18750.000
#
# [26128 rows x 11 columns]

# %%
# W-MON date range from 2020 to 2022
# Left Join Test DF and Time DF
empty_df = pd.DataFrame()
for entry in sample_entry:
    entry_start = min(df_raw.loc[df_raw['entry_id'] == entry]['date'])
    date_range = pd.date_range(entry_start, '2022-05-31', freq = 'W-MON')
    time_df = pd.DataFrame({'date': date_range})
    
    time_df['entry_id_'] = entry
    entry_df = test_df.loc[test_df['entry_id'] == entry]
    joined_df = pd.merge(time_df, entry_df, left_on = ['date'], right_on = ['date'], how = 'left')
    empty_df = empty_df.append(joined_df)

df = empty_df.copy()
df = df.sort_values(by = ['entry_id_', 'date'])
df.set_index(np.arange(len(df)), inplace=True)
len(df.entry_id_.unique())
# Out:
# 998

# %%
# Abnormal Price Range Detection
def exceed_3sigma(array):
    threshold_min = np.min(array) - 3 * np.std(array)
    threshold_max = np.min(array) + 3 * np.std(array)
    if threshold_min < 0:
        threshold_min = 0

    check_col = []
    for i in array:
        if i > threshold_max or i < threshold_min:
            check_col.append(1)
        else:
            check_col.append(0)
    return np.asarray(check_col)

# Count the occurances of consecutive null value
def count_consec_nan(array):
    consec_cnt = array.isnull().astype(int).groupby(array.notnull().astype(int).cumsum()).cumsum()
    return np.asarray(consec_cnt)

one_freq_0_lst1 = []
one_freq_0_lst2 = []
one_freq_not0_lst3 = []
multi_freq_lst1 = []
multi_freq_lst2 = []
multi_freq_lst3 = []
multi_freq_lst4 = []

# -- Alarm -- #
# price change rate
def alarm_1(df):
    df['price_avg_chg'] = np.where(
        (df['price_avg'].notnull()) & (df['price_avg'].shift(1).notnull())
        , df['price_avg'] / df['price_avg'].shift(1)
        , 0)
    df['rank'] = df.groupby('entry_id_')['date'].rank("dense", ascending = True)
    df['price_avg_chg_'] = np.where(df['rank'] == 1, np.nan, df['price_avg_chg'])
    df.drop(['price_avg_chg', 'rank'], axis = 1, inplace = True)
    df['alarm1'] = np.where(df['price_avg_chg_'] > 2, 1, 0)

# consecutive null count
def alarm_2(df):
    # 연속적으로 null 이 보고되는 횟수를 담은 column: consec_null
    # consec_null 의 shift(1) column: consec_null_shift
    df['consec_null'] = df.groupby('entry_id_')['price_avg'].transform(count_consec_nan)
    df['consec_null_shift'] = df.groupby('entry_id_')['consec_null'].shift(1)
    
    # Logic 상세 설명 - consec_null 와 consec_null_shift 비교:
    # entry_id의 Price의 첫 보고일 2020.10.05: consec_null == 0, consec_null_shift == NaN, freq == 0
    # 다음 Price 보고일 2020.10.12: consec_null == 0, consec_null_shift == 0, freq == 1
    # 다음 Price 보고일 2020.10.19: consec_null == 0, consec_null_shift == 0, freq == 1
    # 다음 Price 보고일 2020.11.09(3주차에 보고): consec_null == 0, consec_null_shift == 2, freq == 3
    
    # conditions[0]: Price 첫 보고일 // conditions[1]: 다음 Price 보고일
    # freq 결과값: 첫 보고일 = 0, 다음 보고일 = price 가 보고되지 않고 있던 주기 + 1, 보고 x = price 가 보고되지 않고 있던 주기
    conditions  = [ (df['consec_null'] == 0) & (df['consec_null_shift'].isnull()),
                   (df['consec_null'] == 0) & (df['consec_null_shift'].notnull())]
    choices     = [ 0, df['consec_null_shift'] + 1]
    df["freq"] = np.select(conditions, choices, default=np.nan)
    
    # 해당 entry_id의 Price의 주 보고 기간의 최빈값 계산. 복수 개의 최빈값이 있을 경우, 리스트 형태로 닮김.
    entry_freq = df.groupby('entry_id_')['freq'].agg(pd.Series.mode).to_dict()
    
    # 최빈값 Dict 생성
    threshold_dict = {}
    for entry, freq in entry_freq.items():
        # 최빈값이 단일값만 존재할 경우:
        if isinstance(freq, float):
            # 최빈값이 단일값만 존재하는 경우
            # freq = 0이라는 것은 단 한 번 Price가 보고된 후, 그 이후로는 보고되지 않고 있다는 뜻.
            if freq == 0:
                timedelt = round((pd.Timestamp(2022, 5, 31) - min(df.loc[df['entry_id_'] == entry]['date'])) / np.timedelta64(1, 'M'))
                # 2022/05/31 기준 2개월 이내 추가된 entry일 경우는 threshold를 100으로 설정.
#                 print('freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt = ', entry, freq, timedelt)
                if timedelt <= 2:
                    one_freq_0_lst1.append(entry)
                    threshold_dict[entry] = 100
                # 그렇지 않다면, threshold를 0 으로 설정 (즉, 이 경우에는 무조건 alarm 2에 포함)
                else:
                    one_freq_0_lst2.append(entry)
                    threshold_dict[entry] = 4
            else:
#                 print('freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq', entry, freq)
                one_freq_not0_lst3.append(entry)
#                 threshold_dict[entry] = 100
                threshold_dict[entry] = freq * 2
        # 최빈값이 두 개 이상 존재: 매우 불규칙하게 보고되어서 일정한 주기가 없는 경우
        # 이 때 threshold 설정은 0과 1을 제외한 min값
        else:
            # 최빈값이 [0, 1] 일 경우. 즉 최초 한 번과 바로 그 다음 주기에 price가 보고된 후 한 번도 들어오지 않은 경우
            if (np.min(freq) == 0) & (freq[np.where(freq == np.min(freq))[0][0] + 1] == 1) & (len(freq) == 2) :
                timedelt = round((pd.Timestamp(2022, 5, 31) - min(df.loc[df['entry_id_'] == entry]['date'])) / np.timedelta64(1, 'M'))
#                 print('freq 최빈값이 [0, 1]일 경우: entry, freq =', entry, freq)
                # 2022/05/31 기준 2개월 이내 추가된 entry일 경우는 threshold를 100으로 설정.
                if timedelt <= 2:
                    multi_freq_lst1.append(entry)
                    threshold_dict[entry] = 100
                # 그렇지 않다면, threshold를 0 으로 설정 (즉, 이 경우에는 무조건 alarm 2에 포함)
                else:
                    multi_freq_lst2.append(entry)
                    threshold_dict[entry] = 0
            # 최빈값이 [0,1,3,10,...] 등 최초 한 번 보고된 후에도 매우 불규칙적으로 보고되고 있는 entry일 경우
            else:
            # 위 예시같은 경우 - threshold = 3 (0의 index + 2) x 2
                value = freq[np.where(freq == np.min(freq))[0][0] + 1]
#                 print('freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next', entry, freq, value)
                if value == 1:
                    multi_freq_lst3.append(entry)
                    value = freq[np.where(freq == np.min(freq))[0][0] + 2]
#                     print('freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next', value)
                    threshold_dict[entry] = value * 2
                else:
                    multi_freq_lst4.append(entry)
#                     print('freq 최빈값이 [0, 3, 10...]일 경우, 0 next', value)
                    threshold_dict[entry] = value * 2
    def categorise(row):
        threshold_col = [threshold for entry, threshold in threshold_dict.items() if row['entry_id_'] == entry]
        return np.asarray(threshold_col[0])

    df['threshold_alarm2'] = df.apply(lambda row: categorise(row), axis = 1)
    
    conditions  = [ (df['consec_null'] == 0) & (df['consec_null_shift'].isnull()),
               (df['consec_null'] == 0) & (df['consec_null_shift'].notnull()),
            (df['consec_null'] != 0) & (df['consec_null_shift'].notnull())]
    choices     = [ 0, df['consec_null_shift'] + 1, df['consec_null_shift']]
    
    df["freq_judge"] = np.select(conditions, choices, default=np.nan)
    df['alarm2'] = np.where(df['freq_judge'] >= df['threshold_alarm2'], 1, 0)

# abnormal price
def alarm_3(df):
    group = df.groupby('entry_id_')["price_avg"]
    df['alarm3'] = group.transform(exceed_3sigma)

# constant price
def alarm_4(df):
    df['rank_'] = df.groupby(by = 'entry_id_')['date'].rank("dense", ascending = True)
    df['price_avg_shift'] = np.where(df['rank_'] == 1, np.nan, df['price_avg'].shift(1))
    df.drop(['rank_'], axis = 1, inplace = True)
    df['consec_count_same'] = (df['price_avg'] == df['price_avg_shift']).groupby(
        (df['price_avg'] != df['price_avg_shift']).cumsum()
    ).cumsum()
    threshold_alarm4 = 10
    df['alarm4'] = np.where(df['consec_count_same'] >= threshold_alarm4, 1, 0)
    
# change in number of entries in source 
def alarm_5(df):
    df_source = df.sort_values(by = ['date', 'source_id', 'entry_id_']).copy()
    entry_countBysource = pd.DataFrame(empty_df.groupby(
        by = ['date', 'source_id'])['entry_id_'].count()
                                      ).reset_index(level = (0,1))
    entry_countBysource = entry_countBysource.sort_values(by = ['source_id', 'date'])
    entry_countBysource['diff'] = entry_countBysource['entry_id_'] - entry_countBysource['entry_id_'].shift(1)
    entry_countBysource['Rank'] = entry_countBysource.groupby(by = 'source_id')['date'].rank("dense", ascending = True)
    entry_countBysource['diff_'] = np.where(entry_countBysource['Rank'] == 1, np.nan, entry_countBysource['diff'])
    entry_countBysource.drop(['Rank', 'diff'], axis = 1, inplace = True)

    threshold_alarm5 = 10
    result = entry_countBysource.loc[entry_countBysource['diff_'].abs() > threshold_alarm5]
    result_dict = result.to_dict('records')
    source_list = []
    date_list = []
    for result in result_dict:
        source_list.append(result['source_id'])
        date_list.append(result['date'])

    df['alarm5'] = np.where((df['source_id'].isin(source_list)) & (df['date'].isin(date_list)),
                           1, 0)

# %%
alarm_5(df)
alarm_4(df)
alarm_3(df)
alarm_2(df)
alarm_1(df)
# Out:
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40857878 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40858600 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40858670 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40859109 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40860060 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40860394 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40860587 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40861087 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40861531 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40862095 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40862096 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40862556 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40862858 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40863559 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40863754 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40863763 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40865627 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40867073 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40867419 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40867668 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40867745 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40867867 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40868159 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40868695 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40868795 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40869263 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40869331 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40869537 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40869632 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40870670 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40870760 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40870996 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40871564 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40871981 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40872219 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40872365 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40872915 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40873202 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40873446 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40873670 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40873737 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40873863 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40874310 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40874750 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40874797 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40874806 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40875447 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40876104 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40879264 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40879300 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40881141 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40883035 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40885333 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40885380 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40885699 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40889095 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40889890 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40890003 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40890016 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40890066 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40890791 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40891071 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40891135 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 40891753 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40892676 0.0 29
# freq 최빈값이 [0, 1]일 경우: entry, freq = 40893822 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40895558 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40896407 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40896444 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40896768 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40896880 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40896907 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40896987 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40897370 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40897389 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40897542 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40897850 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40898618 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40898671 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40898754 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40898895 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40898898 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40899118 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40899175 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40899300 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40899506 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40900597 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40900603 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40901482 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40903131 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40903790 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40904422 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40904876 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40905913 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40907892 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40909073 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40909621 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40912226 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40912233 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40912945 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 40912973 [ 0.  1. 15.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 15.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 40914973 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40915450 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40919338 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40919530 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40920325 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40921327 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40921418 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40921720 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40922103 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40922420 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40922531 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40922592 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40922867 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40923392 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40923430 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 40923919 [ 0. 36.] 36.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 36.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40924030 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40924349 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40924372 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40924431 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40925065 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40925616 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40925646 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40925699 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40926175 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40926328 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40927271 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40927288 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40927381 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40927871 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40928837 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40929001 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40929978 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40930050 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40930066 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40930359 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40930988 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40931066 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 40931565 [ 0.  6. 17. 37. 59.] 6.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 6.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40931697 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40932777 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40933708 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40933733 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40935015 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40935276 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40935285 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40935375 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40935556 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40936181 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40936767 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40936942 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40938074 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40939178 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40940325 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40940542 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40942496 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40942825 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40942880 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40943069 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40943747 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40944062 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40944596 3.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 40945086 [ 0.  1.  2. 23. 35. 36.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40945414 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40947123 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40948294 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40948367 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40948805 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40949712 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40951155 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40952165 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40952383 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40953627 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40956251 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40956356 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40958897 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40958909 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40958918 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40961558 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40965171 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40967090 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40967141 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40968147 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40970516 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40970621 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40970790 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40971200 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40971205 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40972840 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40973640 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40973844 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 40973928 [0. 1.]
# freq 최빈값이 [0, 1]일 경우: entry, freq = 40974417 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40975613 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40975652 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40976399 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40978056 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40978673 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40979220 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40979310 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40979650 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40984433 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40985297 0.0 26
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  40985436 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40985443 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40992255 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 40992806 [0. 1. 3. 4. 5.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40993183 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40993342 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40993343 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40994101 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40994133 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40994278 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40995975 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 40996009 [ 0. 66.] 66.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 66.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40996091 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40996326 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40996820 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40997064 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40997505 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40997873 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40998035 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40998483 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40999291 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40999501 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 40999871 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41000912 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41010355 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41012276 0.0 23
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41016855 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41021014 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41029673 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41031848 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41037888 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41040809 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41041665 [0. 3.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41042036 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41042739 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41045333 [0. 1. 3. 9.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41045760 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41046853 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41046910 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41049868 [ 0. 96.] 96.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 96.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41053002 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41056324 0.0 9
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41056477 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41056541 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41056885 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41057705 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41058078 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41058489 0.0 10
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41059292 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41060400 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41065887 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41071080 0.0 8
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41086345 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41087068 [ 0.  3.  9. 30. 44.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41090995 [ 0. 26.] 26.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 26.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41091018 0.0 26
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41091101 [0. 1. 2. 3. 5.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41097769 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41097776 0.0 21
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41107816 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41108588 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41109508 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41111413 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41114129 [0. 4.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41114323 [0. 4.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41114505 [0. 4.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41114961 [0. 4. 5.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41115615 [0. 4.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41116152 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41135273 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41146384 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41150318 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41155229 0.0 7
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41168379 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 41170044 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41171224 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41172134 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41174066 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41180698 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41196634 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41203419 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41203421 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41229244 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 41233068 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41234694 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41235151 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41236357 0.0 24
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41240625 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41242815 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41245799 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41252961 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41264252 0.0 13
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41268018 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41269807 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41287224 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 41292020 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41320341 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41321745 0.0 26
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41328273 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41334209 [0. 1. 3. 4.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41343324 [ 0.  3. 54.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41366160 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41396519 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41415947 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41419124 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41424469 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41425061 [ 0. 86.] 86.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 86.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 41435873 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41438669 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41443122 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41480914 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41509543 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41514324 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41517892 [ 0. 31.] 31.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 31.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41525165 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41533868 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 41581966 [0. 5. 8.] 5.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41600028 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41609653 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41618856 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41621691 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41622603 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41631986 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41636282 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41690085 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 41727780 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41801429 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41869195 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41870946 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41871824 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41874738 0.0 1
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 41904053 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  41925073 0.0 26
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 42151732 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 42296706 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 42408965 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  42486811 0.0 26
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 42866713 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 42937049 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 43052371 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 43184567 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  43408995 0.0 0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  43985244 0.0 19
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 44142381 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 44280510 [0. 4.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 44336745 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  45142055 0.0 24
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  46466723 0.0 8
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47317012 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47437471 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47454195 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47461431 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47488912 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47493561 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47495247 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47496147 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47941251 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 47972917 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48101176 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48437262 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48440144 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48440178 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48440270 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48441111 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48441557 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  48441777 0.0 28
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48441868 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 48441998 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48442014 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48442192 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48454517 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48459270 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48475282 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 48836931 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 49500995 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  49911782 0.0 27
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 50159007 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 50187061 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 50456522 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 50864227 [0. 4. 5.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 50900630 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 50945921 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 50947021 [ 0.  3. 42.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 51001040 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 51003610 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 51019214 [ 0. 17.] 17.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 17.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 51096218 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 51126668 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 51323384 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 51339869 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 51341606 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 52049094 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 52056549 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 52092838 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  52177153 0.0 26
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 52215126 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 52251327 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 53295586 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 53381858 [ 0. 17.] 17.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 17.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 53719278 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 54692647 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 56252299 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 56746327 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 56761123 [1. 2.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 56771154 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 56779472 4.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 56971149 [ 0.  3.  4. 19.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 57002397 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 57137365 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 57278810 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 57372981 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  57483994 0.0 27
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 57491882 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 57541388 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 57888894 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 57899775 [ 0.  1. 50.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 50.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58164075 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58435823 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58637665 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58638825 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58638938 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58639001 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58639015 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  58639167 0.0 24
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58639461 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58639577 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 58639904 [ 0.  5. 26.] 5.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58640172 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58640423 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58642587 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58643289 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58643633 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58644203 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58644595 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58644702 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58648017 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58649749 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58650041 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58650337 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58650751 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58652193 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58654778 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58655008 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58655076 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58655194 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58655228 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 58659020 [ 0. 20. 27. 35.] 20.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 20.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58662400 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58663922 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58665064 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58670675 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 58680932 [0. 2.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58683240 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58686712 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  58697587 0.0 13
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58704724 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58711930 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58789050 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58933753 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 58944479 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 80961831 [0. 9.] 9.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 9.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 80981371 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 80986712 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 80998534 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 81024533 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 81059630 [ 0. 13.] 13.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 13.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 81101844 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 81177140 [0. 4.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 81215662 [ 0. 14.] 14.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 14.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  81243393 0.0 23
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 81684101 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  81779056 0.0 23
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 81829125 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 82612615 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 82619770 [0. 3.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 82628275 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 82699465 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 82737431 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 82769718 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 82791777 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 82791784 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 82878364 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 83016935 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83086671 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83203005 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83251989 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83254218 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83254945 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83255260 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83255597 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83255934 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83612018 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83700851 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83764934 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 83783113 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83939962 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83976910 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 83984578 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84013067 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84014772 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84020844 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  84053874 0.0 22
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84139685 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84203943 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84367461 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84467099 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 84565463 [ 0. 51.] 51.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 51.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84652616 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  84653177 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84802639 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  84840957 0.0 21
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84867383 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 84972017 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 85169149 [ 0. 20.] 20.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 20.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 85358867 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  85395491 0.0 21
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 85734073 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 85973227 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 86182329 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 86426014 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 86710064 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87422051 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  87710424 0.0 20
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87909241 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87909356 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 87911099 [ 0.  1.  4. 19. 23.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87911430 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87911511 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87911783 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87911868 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87914446 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87937546 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87947426 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87961851 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87968355 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87974716 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  87975622 0.0 21
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 87977397 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 88025994 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 88033273 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 88417367 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 88437268 [0. 1.]
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 88443867 [0. 1. 2.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 88453166 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 88546679 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 88702186 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 88840977 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 88911253 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 89069867 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  89071021 0.0 19
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  89346886 0.0 19
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 89352203 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 89398831 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 89408905 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 89456588 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 89501675 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 89759076 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 89784527 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 90091105 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 90255298 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  90439230 0.0 18
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 91097457 [ 0.  1.  8. 11. 21. 37.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 8.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 91281279 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 92295903 [ 0.  7. 10. 11. 12. 37.] 7.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 7.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 92328623 [0. 5.] 5.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 92928365 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 92946862 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 92949040 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  92949114 0.0 18
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 92952246 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 92952557 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 92955501 [4. 5.] 5.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 92955652 5.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 92955984 [4. 5.] 5.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 92958597 [ 0.  1. 61.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 61.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 92959404 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 92959900 [ 0.  1. 60.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 60.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  92961411 0.0 26
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 92961981 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 92962484 [0. 4.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 92992789 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  92997838 0.0 28
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 93258929 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 93301732 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 93399903 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 93515351 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 93596667 [ 0.  1. 53.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 53.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  93718172 0.0 17
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 93757829 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 93858573 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 93880088 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  93943472 0.0 18
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 94371586 [ 0.  5.  8. 18.] 5.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  94466667 0.0 17
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 94660529 [ 0.  1. 45.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 45.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  94769888 0.0 16
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94780688 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  94837215 0.0 19
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  94850473 0.0 19
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  94852580 0.0 19
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94861174 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94876443 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94883780 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94901120 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94945605 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94951352 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94968983 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 94987019 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95044263 0.0 24
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 95081536 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 95098091 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 95202062 [  0. 105.] 105.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 105.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95205195 0.0 26
# freq 최빈값이 [0, 1]일 경우: entry, freq = 95212704 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95215270 0.0 28
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95216308 0.0 27
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95221563 0.0 28
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 95225187 [ 0. 42. 69.] 42.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 42.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 95230164 [ 0. 57.] 57.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 57.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95233411 0.0 29
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95371801 0.0 16
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 95415003 [ 0.  5. 48.] 5.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95417563 0.0 16
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 95488697 [ 0. 14. 19.] 14.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 14.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 95577699 [ 0.  1. 49.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 49.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 95616939 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 95677729 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 95701454 [0. 1. 5.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 95790859 [0. 3.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  95814837 0.0 16
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 95828299 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 95887328 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 95887387 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  96022124 0.0 12
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  96230657 0.0 16
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 96329874 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 96388368 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 96400708 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 96425666 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 96542312 [ 0. 55.] 55.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 55.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 96901002 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 97689836 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 98578430 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  98648883 0.0 7
# freq 최빈값이 [0, 1]일 경우: entry, freq = 98882935 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  98901252 0.0 15
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99056587 4.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 99070441 [0. 3.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  99311376 0.0 15
# freq 최빈값이 [0, 1]일 경우: entry, freq = 99330382 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  99332224 0.0 15
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99332619 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99525533 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99525699 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99525917 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  99533019 0.0 15
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99626074 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99655659 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99656107 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 99718636 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  99738445 0.0 14
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 99914823 [0. 6.] 6.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 6.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  100061193 0.0 14
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 100070245 [ 0.  1. 13.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 13.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  100188633 0.0 14
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100348191 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100351648 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100353341 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100355795 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100355875 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100356600 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 100357674 [ 0. 19.] 19.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 19.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100357962 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100447840 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100561126 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100581085 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 100589377 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 100763771 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 101299356 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 101451253 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 101469270 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  101476635 0.0 13
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 101572196 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  101667583 0.0 13
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 101688404 [ 0.  5. 10.] 5.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 5.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 101835043 [ 0. 19.] 19.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 19.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102006256 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  102029442 0.0 12
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102089559 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102178865 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102429485 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  102484947 0.0 12
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102492892 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 102568625 [0. 2.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  102793296 0.0 12
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  102828936 0.0 12
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102839939 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102842386 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102900831 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102901003 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102902755 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102905256 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 102912892 3.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 102914306 [0. 1.]
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 102947136 [ 0. 17.] 17.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 17.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103020186 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103026903 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103031841 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  103034620 0.0 28
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  103040356 0.0 6
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103043033 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 103452723 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  103580399 0.0 11
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  103698677 0.0 16
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103746150 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103783257 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103790537 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103791419 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 103830162 [ 0. 60.] 60.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 60.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103843497 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  103847462 0.0 21
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103916524 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 103917778 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 103937506 [ 0.  1. 25.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 25.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104097009 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  104284943 0.0 11
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104291411 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104346568 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104419051 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104494367 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104514884 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  104548836 0.0 13
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104549899 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104557952 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  104562265 0.0 14
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104562287 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104577352 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 104597087 [ 0.  3. 35.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  104630595 0.0 21
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  104735346 0.0 10
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 104816189 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 104943901 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  105035479 0.0 17
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105048612 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 105164076 [0. 1. 6.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 6.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105167518 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  105187962 0.0 10
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105192352 4.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  105226177 0.0 10
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  105236158 0.0 10
# freq 최빈값이 [0, 1]일 경우: entry, freq = 105292093 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  105331989 0.0 9
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105412974 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 105443718 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105463375 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105470493 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105478224 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105478916 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 105482731 [0. 1.]
# freq 최빈값이 [0, 1]일 경우: entry, freq = 105488724 [0. 1.]
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 105505901 [ 0. 37.] 37.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 37.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105529030 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105538000 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105546736 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105572239 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  105636848 0.0 9
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105650960 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105752755 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105796978 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105801728 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 105801979 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 105844478 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  105893001 0.0 9
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  106034655 0.0 9
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 106207456 [0. 1. 2. 7.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 106216875 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 106483358 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 106484514 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 106486227 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 106487127 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 106585880 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 107033435 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  107075536 0.0 8
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  107076517 0.0 8
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  107078606 0.0 8
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  107079970 0.0 8
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  107080486 0.0 8
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 107125960 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 107281843 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 108681526 [0. 4. 5.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 108765322 [ 0.  1.  8. 18.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 8.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 108829029 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  108935126 0.0 7
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 109037384 [0. 2. 5.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  109058932 0.0 7
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 109090257 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 109098434 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 109179624 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 109180640 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 109285868 [0. 1. 4.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  109405090 0.0 7
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  109528294 0.0 7
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  109567562 0.0 7
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 109817075 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  109834449 0.0 7
# freq 최빈값이 [0, 1]일 경우: entry, freq = 109852962 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 109994836 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110022055 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110026054 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110146870 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  110161904 0.0 7
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110353513 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110390125 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110432182 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110469698 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  110579145 0.0 6
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110649372 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110796930 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  110913782 0.0 6
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  110914824 0.0 7
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 110917539 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 111008531 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 111189291 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  111192611 0.0 6
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  111260290 0.0 6
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 111281609 [ 0. 18.] 18.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 18.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  111306696 0.0 6
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  111335826 0.0 6
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 111342209 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 111409146 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 111640941 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 111824248 [0. 2.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 111871783 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 111925566 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  112040494 0.0 6
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112131911 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  112248586 0.0 6
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  112344091 0.0 6
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 112446720 [ 0. 13.] 13.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 13.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112649024 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112650494 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112657852 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  112659550 0.0 29
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112664003 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112698354 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112978620 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112989108 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 112996479 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 113001862 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 113028962 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 113082211 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  113090757 0.0 21
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 113125663 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 113131774 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 113133672 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  113172442 0.0 23
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 113197479 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 113211927 [0. 1.]
# freq 최빈값이 [0, 1]일 경우: entry, freq = 113217995 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  113282626 0.0 25
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  113325385 0.0 26
# freq 최빈값이 [0, 1]일 경우: entry, freq = 113508868 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 114924607 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 115042320 [0. 3.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 115134776 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 115294237 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 115448705 [0. 2. 5.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 115524067 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 115551856 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 115689295 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  115708165 0.0 5
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 115726307 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 115793067 [0. 7.] 7.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 7.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 115812929 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 115815643 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  115815694 0.0 5
# freq 최빈값이 [0, 1]일 경우: entry, freq = 115817971 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  115819074 0.0 5
# freq 최빈값이 [0, 1]일 경우: entry, freq = 115845322 [0. 1.]
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  115927895 0.0 4
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 115958554 [0. 1. 6.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 6.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116262653 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116309633 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116309745 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116309772 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116310478 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116310703 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116311003 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116311663 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  116312115 0.0 4
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116312394 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116312475 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116313018 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116313455 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116313477 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116313570 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116313598 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116313685 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116313980 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116314103 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116314246 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116314369 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116377296 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116380579 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  116418113 0.0 4
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  116476169 0.0 4
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116599903 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 116808638 [0. 1. 2.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  116831386 0.0 4
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116880680 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 116921749 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  116925480 0.0 4
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117027459 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117309870 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117313176 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117313487 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 117313825 [0. 1. 3. 4.] 1.0
# freq 최빈값이 [0, 1, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117313996 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117314067 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117314228 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117318257 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117331877 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117342921 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117344858 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 117836300 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 117880614 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  117978150 0.0 3
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  118048632 0.0 4
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118103315 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118184625 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118227420 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118238726 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118377194 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118418949 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118419846 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  118556806 0.0 3
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118789304 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 118793107 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  118811691 0.0 3
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  118900833 0.0 3
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 119344431 [0. 3.] 3.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 3.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 119373567 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 119398171 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  119536169 0.0 3
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  119661055 0.0 6
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  119665291 0.0 5
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  119665442 0.0 6
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  120052728 0.0 2
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  120131736 0.0 8
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120131826 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120132465 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  120132751 0.0 7
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120134191 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120174187 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  120240438 0.0 5
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120244592 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120277152 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120325619 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120501397 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 120505019 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 120567626 1.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 121380403 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 121385045 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 121385487 [0. 4.] 4.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 4.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 121386320 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 121387335 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 121387472 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 121388968 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  121392019 0.0 2
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 121396445 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 121452094 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 121490172 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  123551904 0.0 2
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 124241420 [1. 2.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 127828808 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 131715069 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 131888319 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 131938158 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 132045214 1.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  132714762 0.0 1
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 132773970 [0. 2.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 132812563 [0. 1.]
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 132813331 1.0
# freq 최빈값이 단일값이며 0이 아닐 경우: entry, freq 132834999 1.0
# freq 최빈값이 [0, 1] 이외에도 있는 경우: entry, freq, 0 next 132904838 [0. 2.] 2.0
# freq 최빈값이 [0, 3, 10...]일 경우, 0 next 2.0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  132918138 0.0 1
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  133199278 0.0 0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  133535519 0.0 0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  133747531 0.0 0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  133878965 0.0 0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  133882210 0.0 0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  133882962 0.0 0
# freq 최빈값이 단일값이며 0일 경우: entry, freq, timedelt =  134082497 0.0 0
# freq 최빈값이 [0, 1]일 경우: entry, freq = 134278888 [0. 1.]

# %%
df_latest = df.loc[(df['date'] >= '2022-03-01') & (df['date'] < '2022-05-31')].copy()

# %%
print(f'df_raw -> random sampling {len(sample_entry)} entries')
print('total number of entries: ', len(df_latest['entry_id_'].unique()))
print('alarm_5: change in # of entries in each source', len(df_latest[df_latest['alarm5'] == 1]))
print('alarm_4: constant price', len(df_latest[df_latest['alarm4'] == 1]))
print('alarm_3: abnormal price range', len(df_latest[df_latest['alarm3'] == 1]))
print('alarm_2: exceed price report frequency - # of entries ', len((df_latest.loc[df_latest['alarm2'] == 1]['entry_id_']).unique()))
print('alarm_1: price change rate (200%) ', len(df_latest[df_latest['alarm1'] == 1]))

print('''
## Point 1
alarm 5 threshold = 10: source 별로 묶여 있는 entry 개수가 너무 다르기 때문에, threshold를 entry마다 달리 설정할 필요성이 있어 보임. 기준을 별도로 정해야 할 필요성이 있음.
alarm 4 threshold = 10: 이는 기준을 비교적 정성적으로 정해도 될 것으로 판단 됨.
alarm 3 threshold = confidence level (99): 기준을 별도로 정해야 할 필요성이 있음.
alarm 2 threshold = 3: 이는 기준을 비교적 정성적으로 정해도 될 것으로 판단 됨.
alarm 1 threshold = 200%: 이는 기준을 비교적 정성적으로 정해도 될 것으로 판단 됨.
''')
# Out:
# df_raw -> random sampling 1000 entries
# total number of entries:  998
# alarm_5: change in # of entries in each source 116
# alarm_4: constant price 61
# alarm_3: abnormal price range 414
# alarm_2: exceed price report frequency - # of entries  931
# alarm_1: price change rate (200%)  9
#
# ## Point 1
# alarm 5 threshold = 10: source 별로 묶여 있는 entry 개수가 너무 다르기 때문에, threshold를 entry마다 달리 설정할 필요성이 있어 보임. 기준을 별도로 정해야 할 필요성이 있음.
# alarm 4 threshold = 10: 이는 기준을 비교적 정성적으로 정해도 될 것으로 판단 됨.
# alarm 3 threshold = confidence level (99): 기준을 별도로 정해야 할 필요성이 있음.
# alarm 2 threshold = 3: 이는 기준을 비교적 정성적으로 정해도 될 것으로 판단 됨.
# alarm 1 threshold = 200%: 이는 기준을 비교적 정성적으로 정해도 될 것으로 판단 됨.

# %%
print(len(one_freq_0_lst1),
len(one_freq_0_lst2),
len(one_freq_not0_lst3),
len(multi_freq_lst1),
len(multi_freq_lst2),
len(multi_freq_lst3),
len(multi_freq_lst4))
# Out:
# 14 142 703 5 40 25 69

# %%
alarm2_lst = df.loc[df['alarm2'] == 1]['entry_id_'].unique()

# %%
# mode final
df.groupby('entry_id_')['freq'].agg(pd.Series.mode).to_csv('final.csv')
# alarm2 sample
df.loc[(df['entry_id_'].isin(alarm2_lst))].to_csv('alarm2_sample.csv')
# individual sample
df.loc[(df['entry_id_'] == 123551904)].to_csv('sample_individual.csv')

# %%
# df.drop(['entry_id', 'consec_null_shift', 'price_avg_shift', 'price_avg_chg_'])
